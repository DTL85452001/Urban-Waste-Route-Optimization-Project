# %% [markdown]
# # Urban Waste Management Optimization

# %% [markdown]
# ### This project will use historical data to uncover time-based and material-based inefficiencies that will inform smarter waste management decisions.

# %% [markdown]
# ### For the first part of this project, I will examine Recycling_Diversion_and_Capture_Rates_20250603.csv from NYC Open Data. After reviewing the file, no data appears to be missing. There are 9 columns consisting of data that are categorical and quantitative. For us to create our initial analysis of the data, we will need to create five dictionaries. But to make this process easier, we will first need to organize the data by month and year. To do this, we will first create a function that provide the sort keys needed to organize our data.

# %%
def fiscal_sort_key(row):
    # Convert to integers so that sorting works numerically
    year = int(row['Fiscal Year'])
    month = int(row['Fiscal Month Number'])
    return (year, month)

# %% [markdown]
# ### Now that we have created a function that will extract the two values we wish to sort by. We will now create a function that will load all rows and use sorted with the function from before.

# %%
import csv

def load_all_rows(file):
    with open(file, newline='') as file:
        # Will take our file, take the first row as our keys, and then for each row will assign the data to the key from our first row.
        reader = csv.DictReader(file)
        # Will return a list where each element in the list is a dictionary
        return list(reader)
    
rows = load_all_rows('Recycling_Diversion_and_Capture_Rates_20250603.csv')
from collections import defaultdict
# Will create a an empty dictionary where the key is any information you provided it and the value will be an empty list.
borough_groups = defaultdict(list)
for row in rows:
    # Will create a dictionary where the zone is the new key, since nothing exists there, and borough_groups is being used, it will go to the empty list and append the row, which is a 
    # which is a dictionary, grouping each row by zone
    borough_groups[row['Zone']].append(row)
# Creates a new dictionary where its is organizing each borough by the year and month
sorted_boroughs = {
    borough: sorted(records, key=fiscal_sort_key)
    for borough, records in borough_groups.items()
}

# %% [markdown]
# ### Now that we have create a dictionary that has boroughs sorted by year and month starting from 2016 to 2019 and so forth, we will now create a list to store the information.

# %%
sorted_records = []
# Will access the borough in alphabetical order.
for borough in sorted(sorted_boroughs.keys()):
    # Will access a row (where the row is a dictionary) and will select the value of that row for each of the following elements
    for row in sorted_boroughs[borough]:
        district = row['District']
        year = row['Fiscal Year']
        # Will take the string number and make the number be in two digits, useful for when organizing by yyyy-mm format
        month = f"{int(row['Fiscal Month Number']):02}"
        diversion = row['Diversion Rate-Total (Total Recycling / Total Waste)']
        capture_paper = row['Capture Rate-Paper (Total Paper / Max Paper)']
        capture_mgp = row['Capture Rate-MGP (Total MGP / Max MGP)']
        capture_total = row['Capture Rate-Total ((Total Recycling - Leaves (Recycling)) / (Max Paper + Max MGP))x100']
        # Will take the above variable at that particular row and append it to list where each item is a dictionary for that borough
        sorted_records.append({
            "Borough": borough,
            "District": district,
            "Fiscal Year": year,
            "Fiscal Month": month,
            "Diversion Rate (%)": diversion,
            "Capture Rate - Paper (%)": capture_paper,
            "Capture Rate - MGP (%)": capture_mgp,
            "Capture Rate - Total (%)": capture_total
        })

# %%
for row in sorted_records:
    print(row)
# Out:
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '5.9', 'Capture Rate - Paper (%)': '17.1', 'Capture Rate - MGP (%)': '21.6', 'Capture Rate - Total (%)': '19.0'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '11.4', 'Capture Rate - Paper (%)': '30.0', 'Capture Rate - MGP (%)': '45.3', 'Capture Rate - Total (%)': '36.5'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '8.5', 'Capture Rate - Paper (%)': '23.8', 'Capture Rate - MGP (%)': '31.5', 'Capture Rate - Total (%)': '27.1'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '9.8', 'Capture Rate - Paper (%)': '26.3', 'Capture Rate - MGP (%)': '38.0', 'Capture Rate - Total (%)': '31.3'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '10.9', 'Capture Rate - Paper (%)': '26.2', 'Capture Rate - MGP (%)': '46.3', 'Capture Rate - Total (%)': '34.9'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '11.0', 'Capture Rate - Paper (%)': '34.1', 'Capture Rate - MGP (%)': '36.7', 'Capture Rate - Total (%)': '35.2'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '12.7', 'Capture Rate - Paper (%)': '32.1', 'Capture Rate - MGP (%)': '52.0', 'Capture Rate - Total (%)': '40.7'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '19.6', 'Capture Rate - Paper (%)': '41.8', 'Capture Rate - MGP (%)': '73.4', 'Capture Rate - Total (%)': '52.0'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '8.8', 'Capture Rate - Paper (%)': '22.6', 'Capture Rate - MGP (%)': '32.1', 'Capture Rate - Total (%)': '26.9'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '17.7', 'Capture Rate - Paper (%)': '41.9', 'Capture Rate - MGP (%)': '59.4', 'Capture Rate - Total (%)': '48.8'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '13.7', 'Capture Rate - Paper (%)': '35.0', 'Capture Rate - MGP (%)': '47.5', 'Capture Rate - Total (%)': '40.0'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '15.5', 'Capture Rate - Paper (%)': '33.6', 'Capture Rate - MGP (%)': '62.9', 'Capture Rate - Total (%)': '45.2'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '6.3', 'Capture Rate - Paper (%)': '17.1', 'Capture Rate - MGP (%)': '23.9', 'Capture Rate - Total (%)': '20.0'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '11.2', 'Capture Rate - Paper (%)': '28.2', 'Capture Rate - MGP (%)': '46.2', 'Capture Rate - Total (%)': '35.9'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '8.3', 'Capture Rate - Paper (%)': '21.5', 'Capture Rate - MGP (%)': '33.5', 'Capture Rate - Total (%)': '26.7'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '9.9', 'Capture Rate - Paper (%)': '25.1', 'Capture Rate - MGP (%)': '40.5', 'Capture Rate - Total (%)': '31.7'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '11.2', 'Capture Rate - Paper (%)': '25.8', 'Capture Rate - MGP (%)': '48.9', 'Capture Rate - Total (%)': '35.7'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '11.1', 'Capture Rate - Paper (%)': '32.9', 'Capture Rate - MGP (%)': '38.8', 'Capture Rate - Total (%)': '35.4'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '12.8', 'Capture Rate - Paper (%)': '30.5', 'Capture Rate - MGP (%)': '54.8', 'Capture Rate - Total (%)': '40.9'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '19.7', 'Capture Rate - Paper (%)': '41.7', 'Capture Rate - MGP (%)': '75.1', 'Capture Rate - Total (%)': '52.5'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '8.8', 'Capture Rate - Paper (%)': '22.0', 'Capture Rate - MGP (%)': '32.9', 'Capture Rate - Total (%)': '27.0'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '17.9', 'Capture Rate - Paper (%)': '41.3', 'Capture Rate - MGP (%)': '62.1', 'Capture Rate - Total (%)': '49.6'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '13.9', 'Capture Rate - Paper (%)': '35.3', 'Capture Rate - MGP (%)': '48.2', 'Capture Rate - Total (%)': '40.4'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '15.8', 'Capture Rate - Paper (%)': '33.3', 'Capture Rate - MGP (%)': '65.6', 'Capture Rate - Total (%)': '46.2'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '6.4', 'Capture Rate - Paper (%)': '19.7', 'Capture Rate - MGP (%)': '23.0', 'Capture Rate - Total (%)': '21.1'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '12.1', 'Capture Rate - Paper (%)': '32.0', 'Capture Rate - MGP (%)': '50.0', 'Capture Rate - Total (%)': '39.9'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '8.8', 'Capture Rate - Paper (%)': '25.2', 'Capture Rate - MGP (%)': '33.4', 'Capture Rate - Total (%)': '28.8'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '10.0', 'Capture Rate - Paper (%)': '27.7', 'Capture Rate - MGP (%)': '39.7', 'Capture Rate - Total (%)': '32.9'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '11.2', 'Capture Rate - Paper (%)': '28.2', 'Capture Rate - MGP (%)': '47.8', 'Capture Rate - Total (%)': '36.7'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '12.6', 'Capture Rate - Paper (%)': '34.9', 'Capture Rate - MGP (%)': '37.4', 'Capture Rate - Total (%)': '36.0'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '12.9', 'Capture Rate - Paper (%)': '33.2', 'Capture Rate - MGP (%)': '54.5', 'Capture Rate - Total (%)': '42.5'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '20.1', 'Capture Rate - Paper (%)': '45.6', 'Capture Rate - MGP (%)': '79.2', 'Capture Rate - Total (%)': '56.3'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '9.1', 'Capture Rate - Paper (%)': '26.2', 'Capture Rate - MGP (%)': '35.5', 'Capture Rate - Total (%)': '30.4'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '18.3', 'Capture Rate - Paper (%)': '42.7', 'Capture Rate - MGP (%)': '75.3', 'Capture Rate - Total (%)': '53.8'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '14.0', 'Capture Rate - Paper (%)': '35.3', 'Capture Rate - MGP (%)': '60.1', 'Capture Rate - Total (%)': '43.7'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '16.3', 'Capture Rate - Paper (%)': '34.8', 'Capture Rate - MGP (%)': '81.3', 'Capture Rate - Total (%)': '50.7'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '6.3', 'Capture Rate - Paper (%)': '18.8', 'Capture Rate - MGP (%)': '23.3', 'Capture Rate - Total (%)': '20.8'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '11.6', 'Capture Rate - Paper (%)': '30.2', 'Capture Rate - MGP (%)': '48.7', 'Capture Rate - Total (%)': '38.3'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '8.6', 'Capture Rate - Paper (%)': '24.5', 'Capture Rate - MGP (%)': '33.0', 'Capture Rate - Total (%)': '28.2'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '10.1', 'Capture Rate - Paper (%)': '28.0', 'Capture Rate - MGP (%)': '39.9', 'Capture Rate - Total (%)': '33.2'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '11.1', 'Capture Rate - Paper (%)': '27.8', 'Capture Rate - MGP (%)': '47.5', 'Capture Rate - Total (%)': '36.4'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '13.4', 'Capture Rate - Paper (%)': '32.9', 'Capture Rate - MGP (%)': '35.9', 'Capture Rate - Total (%)': '34.2'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '12.7', 'Capture Rate - Paper (%)': '31.8', 'Capture Rate - MGP (%)': '54.3', 'Capture Rate - Total (%)': '41.6'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '19.7', 'Capture Rate - Paper (%)': '44.8', 'Capture Rate - MGP (%)': '76.6', 'Capture Rate - Total (%)': '54.9'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '8.9', 'Capture Rate - Paper (%)': '25.2', 'Capture Rate - MGP (%)': '34.8', 'Capture Rate - Total (%)': '29.5'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '18.2', 'Capture Rate - Paper (%)': '43.0', 'Capture Rate - MGP (%)': '72.3', 'Capture Rate - Total (%)': '53.0'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '13.9', 'Capture Rate - Paper (%)': '35.9', 'Capture Rate - MGP (%)': '57.7', 'Capture Rate - Total (%)': '43.3'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '15.8', 'Capture Rate - Paper (%)': '33.8', 'Capture Rate - MGP (%)': '78.7', 'Capture Rate - Total (%)': '49.1'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '5.9', 'Capture Rate - Paper (%)': '17.2', 'Capture Rate - MGP (%)': '22.4', 'Capture Rate - Total (%)': '19.4'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '10.1', 'Capture Rate - Paper (%)': '25.6', 'Capture Rate - MGP (%)': '42.9', 'Capture Rate - Total (%)': '33.2'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '8.3', 'Capture Rate - Paper (%)': '23.1', 'Capture Rate - MGP (%)': '33.1', 'Capture Rate - Total (%)': '27.4'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '9.8', 'Capture Rate - Paper (%)': '27.1', 'Capture Rate - MGP (%)': '39.0', 'Capture Rate - Total (%)': '32.3'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '10.9', 'Capture Rate - Paper (%)': '26.9', 'Capture Rate - MGP (%)': '47.3', 'Capture Rate - Total (%)': '35.8'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '12.9', 'Capture Rate - Paper (%)': '33.3', 'Capture Rate - MGP (%)': '37.1', 'Capture Rate - Total (%)': '35.0'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '12.2', 'Capture Rate - Paper (%)': '30.1', 'Capture Rate - MGP (%)': '52.9', 'Capture Rate - Total (%)': '40.1'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '19.8', 'Capture Rate - Paper (%)': '43.5', 'Capture Rate - MGP (%)': '73.6', 'Capture Rate - Total (%)': '53.0'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '8.2', 'Capture Rate - Paper (%)': '23.0', 'Capture Rate - MGP (%)': '32.2', 'Capture Rate - Total (%)': '27.2'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '18.0', 'Capture Rate - Paper (%)': '41.5', 'Capture Rate - MGP (%)': '68.6', 'Capture Rate - Total (%)': '50.7'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '12.8', 'Capture Rate - Paper (%)': '33.3', 'Capture Rate - MGP (%)': '52.8', 'Capture Rate - Total (%)': '40.0'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '14.7', 'Capture Rate - Paper (%)': '32.4', 'Capture Rate - MGP (%)': '71.6', 'Capture Rate - Total (%)': '45.8'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '6.4', 'Capture Rate - Paper (%)': '19.1', 'Capture Rate - MGP (%)': '22.6', 'Capture Rate - Total (%)': '20.7'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '13.0', 'Capture Rate - Paper (%)': '35.6', 'Capture Rate - MGP (%)': '49.8', 'Capture Rate - Total (%)': '42.0'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '10.0', 'Capture Rate - Paper (%)': '28.7', 'Capture Rate - MGP (%)': '36.5', 'Capture Rate - Total (%)': '32.2'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '10.7', 'Capture Rate - Paper (%)': '30.5', 'Capture Rate - MGP (%)': '39.5', 'Capture Rate - Total (%)': '34.5'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '11.8', 'Capture Rate - Paper (%)': '30.8', 'Capture Rate - MGP (%)': '46.4', 'Capture Rate - Total (%)': '37.8'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '13.2', 'Capture Rate - Paper (%)': '37.1', 'Capture Rate - MGP (%)': '37.6', 'Capture Rate - Total (%)': '37.3'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '14.4', 'Capture Rate - Paper (%)': '38.5', 'Capture Rate - MGP (%)': '56.0', 'Capture Rate - Total (%)': '46.4'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '22.1', 'Capture Rate - Paper (%)': '44.5', 'Capture Rate - MGP (%)': '78.4', 'Capture Rate - Total (%)': '55.1'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '9.8', 'Capture Rate - Paper (%)': '25.1', 'Capture Rate - MGP (%)': '39.8', 'Capture Rate - Total (%)': '31.1'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '20.3', 'Capture Rate - Paper (%)': '47.7', 'Capture Rate - MGP (%)': '65.5', 'Capture Rate - Total (%)': '54.2'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '15.2', 'Capture Rate - Paper (%)': '37.3', 'Capture Rate - MGP (%)': '51.6', 'Capture Rate - Total (%)': '42.5'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '17.4', 'Capture Rate - Paper (%)': '37.1', 'Capture Rate - MGP (%)': '69.4', 'Capture Rate - Total (%)': '48.8'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '5.9', 'Capture Rate - Paper (%)': '16.9', 'Capture Rate - MGP (%)': '20.4', 'Capture Rate - Total (%)': '18.5'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '13.4', 'Capture Rate - Paper (%)': '32.7', 'Capture Rate - MGP (%)': '52.1', 'Capture Rate - Total (%)': '41.4'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '7.6', 'Capture Rate - Paper (%)': '19.8', 'Capture Rate - MGP (%)': '29.5', 'Capture Rate - Total (%)': '24.2'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '9.6', 'Capture Rate - Paper (%)': '25.1', 'Capture Rate - MGP (%)': '35.7', 'Capture Rate - Total (%)': '29.8'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '10.4', 'Capture Rate - Paper (%)': '24.4', 'Capture Rate - MGP (%)': '43.2', 'Capture Rate - Total (%)': '32.9'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '11.4', 'Capture Rate - Paper (%)': '29.8', 'Capture Rate - MGP (%)': '31.6', 'Capture Rate - Total (%)': '30.6'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '12.4', 'Capture Rate - Paper (%)': '29.0', 'Capture Rate - MGP (%)': '49.8', 'Capture Rate - Total (%)': '38.3'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '18.2', 'Capture Rate - Paper (%)': '35.0', 'Capture Rate - MGP (%)': '64.3', 'Capture Rate - Total (%)': '44.2'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '8.8', 'Capture Rate - Paper (%)': '20.8', 'Capture Rate - MGP (%)': '36.0', 'Capture Rate - Total (%)': '27.0'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '18.0', 'Capture Rate - Paper (%)': '38.5', 'Capture Rate - MGP (%)': '62.3', 'Capture Rate - Total (%)': '47.2'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '13.7', 'Capture Rate - Paper (%)': '30.1', 'Capture Rate - MGP (%)': '48.8', 'Capture Rate - Total (%)': '36.9'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '07', 'Diversion Rate (%)': '15.2', 'Capture Rate - Paper (%)': '29.4', 'Capture Rate - MGP (%)': '64.2', 'Capture Rate - Total (%)': '42.1'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '7.7', 'Capture Rate - Paper (%)': '21.5', 'Capture Rate - MGP (%)': '29.1', 'Capture Rate - Total (%)': '24.9'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '13.2', 'Capture Rate - Paper (%)': '35.5', 'Capture Rate - MGP (%)': '51.1', 'Capture Rate - Total (%)': '42.5'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '10.8', 'Capture Rate - Paper (%)': '29.6', 'Capture Rate - MGP (%)': '41.4', 'Capture Rate - Total (%)': '34.9'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '12.2', 'Capture Rate - Paper (%)': '31.8', 'Capture Rate - MGP (%)': '48.1', 'Capture Rate - Total (%)': '39.1'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '13.1', 'Capture Rate - Paper (%)': '31.2', 'Capture Rate - MGP (%)': '55.9', 'Capture Rate - Total (%)': '42.3'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '15.0', 'Capture Rate - Paper (%)': '40.5', 'Capture Rate - MGP (%)': '48.4', 'Capture Rate - Total (%)': '44.0'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '15.3', 'Capture Rate - Paper (%)': '37.2', 'Capture Rate - MGP (%)': '63.7', 'Capture Rate - Total (%)': '49.1'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '23.1', 'Capture Rate - Paper (%)': '45.4', 'Capture Rate - MGP (%)': '89.0', 'Capture Rate - Total (%)': '59.1'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '10.5', 'Capture Rate - Paper (%)': '25.4', 'Capture Rate - MGP (%)': '44.2', 'Capture Rate - Total (%)': '33.1'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '20.8', 'Capture Rate - Paper (%)': '46.5', 'Capture Rate - MGP (%)': '74.2', 'Capture Rate - Total (%)': '56.6'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '16.9', 'Capture Rate - Paper (%)': '39.3', 'Capture Rate - MGP (%)': '61.3', 'Capture Rate - Total (%)': '47.3'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '08', 'Diversion Rate (%)': '18.7', 'Capture Rate - Paper (%)': '36.3', 'Capture Rate - MGP (%)': '80.5', 'Capture Rate - Total (%)': '52.4'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '6.5', 'Capture Rate - Paper (%)': '19.2', 'Capture Rate - MGP (%)': '23.2', 'Capture Rate - Total (%)': '21.0'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '12.6', 'Capture Rate - Paper (%)': '33.2', 'Capture Rate - MGP (%)': '49.8', 'Capture Rate - Total (%)': '40.7'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '9.9', 'Capture Rate - Paper (%)': '26.8', 'Capture Rate - MGP (%)': '37.8', 'Capture Rate - Total (%)': '31.8'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '11.1', 'Capture Rate - Paper (%)': '28.6', 'Capture Rate - MGP (%)': '44.1', 'Capture Rate - Total (%)': '35.6'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '11.8', 'Capture Rate - Paper (%)': '28.9', 'Capture Rate - MGP (%)': '49.4', 'Capture Rate - Total (%)': '38.1'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '13.9', 'Capture Rate - Paper (%)': '34.7', 'Capture Rate - MGP (%)': '39.3', 'Capture Rate - Total (%)': '36.8'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '13.3', 'Capture Rate - Paper (%)': '32.3', 'Capture Rate - MGP (%)': '55.7', 'Capture Rate - Total (%)': '42.8'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '20.2', 'Capture Rate - Paper (%)': '39.5', 'Capture Rate - MGP (%)': '76.1', 'Capture Rate - Total (%)': '51.0'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '9.3', 'Capture Rate - Paper (%)': '22.5', 'Capture Rate - MGP (%)': '39.4', 'Capture Rate - Total (%)': '29.4'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '18.0', 'Capture Rate - Paper (%)': '38.9', 'Capture Rate - MGP (%)': '64.6', 'Capture Rate - Total (%)': '48.2'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '14.2', 'Capture Rate - Paper (%)': '32.4', 'Capture Rate - MGP (%)': '52.5', 'Capture Rate - Total (%)': '39.7'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '09', 'Diversion Rate (%)': '16.5', 'Capture Rate - Paper (%)': '32.2', 'Capture Rate - MGP (%)': '70.9', 'Capture Rate - Total (%)': '46.3'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '6.8', 'Capture Rate - Paper (%)': '19.7', 'Capture Rate - MGP (%)': '26.8', 'Capture Rate - Total (%)': '22.8'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '12.5', 'Capture Rate - Paper (%)': '32.3', 'Capture Rate - MGP (%)': '54.3', 'Capture Rate - Total (%)': '41.9'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '10.1', 'Capture Rate - Paper (%)': '28.0', 'Capture Rate - MGP (%)': '41.4', 'Capture Rate - Total (%)': '33.9'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '10.9', 'Capture Rate - Paper (%)': '28.6', 'Capture Rate - MGP (%)': '47.1', 'Capture Rate - Total (%)': '36.7'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '11.9', 'Capture Rate - Paper (%)': '28.7', 'Capture Rate - MGP (%)': '54.1', 'Capture Rate - Total (%)': '39.8'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '14.0', 'Capture Rate - Paper (%)': '36.6', 'Capture Rate - MGP (%)': '45.3', 'Capture Rate - Total (%)': '40.4'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '13.3', 'Capture Rate - Paper (%)': '32.7', 'Capture Rate - MGP (%)': '60.2', 'Capture Rate - Total (%)': '44.7'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '20.2', 'Capture Rate - Paper (%)': '47.1', 'Capture Rate - MGP (%)': '81.3', 'Capture Rate - Total (%)': '58.8'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '9.2', 'Capture Rate - Paper (%)': '21.5', 'Capture Rate - MGP (%)': '39.4', 'Capture Rate - Total (%)': '28.8'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '17.8', 'Capture Rate - Paper (%)': '42.2', 'Capture Rate - MGP (%)': '67.3', 'Capture Rate - Total (%)': '51.7'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '14.0', 'Capture Rate - Paper (%)': '35.7', 'Capture Rate - MGP (%)': '54.1', 'Capture Rate - Total (%)': '42.7'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '10', 'Diversion Rate (%)': '16.4', 'Capture Rate - Paper (%)': '35.2', 'Capture Rate - MGP (%)': '74.6', 'Capture Rate - Total (%)': '50.1'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '6.5', 'Capture Rate - Paper (%)': '19.0', 'Capture Rate - MGP (%)': '25.3', 'Capture Rate - Total (%)': '21.8'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '12.3', 'Capture Rate - Paper (%)': '31.4', 'Capture Rate - MGP (%)': '54.2', 'Capture Rate - Total (%)': '41.4'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '9.7', 'Capture Rate - Paper (%)': '26.1', 'Capture Rate - MGP (%)': '41.3', 'Capture Rate - Total (%)': '32.7'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '10.7', 'Capture Rate - Paper (%)': '28.1', 'Capture Rate - MGP (%)': '45.8', 'Capture Rate - Total (%)': '35.8'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '11.6', 'Capture Rate - Paper (%)': '28.5', 'Capture Rate - MGP (%)': '52.4', 'Capture Rate - Total (%)': '39.0'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '13.8', 'Capture Rate - Paper (%)': '37.1', 'Capture Rate - MGP (%)': '41.1', 'Capture Rate - Total (%)': '38.8'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '13.1', 'Capture Rate - Paper (%)': '32.6', 'Capture Rate - MGP (%)': '58.8', 'Capture Rate - Total (%)': '44.0'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '20.0', 'Capture Rate - Paper (%)': '47.5', 'Capture Rate - MGP (%)': '78.6', 'Capture Rate - Total (%)': '58.2'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '9.1', 'Capture Rate - Paper (%)': '21.4', 'Capture Rate - MGP (%)': '38.6', 'Capture Rate - Total (%)': '28.4'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '17.7', 'Capture Rate - Paper (%)': '41.5', 'Capture Rate - MGP (%)': '65.8', 'Capture Rate - Total (%)': '50.8'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '13.8', 'Capture Rate - Paper (%)': '35.2', 'Capture Rate - MGP (%)': '53.5', 'Capture Rate - Total (%)': '42.2'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '11', 'Diversion Rate (%)': '15.6', 'Capture Rate - Paper (%)': '34.0', 'Capture Rate - MGP (%)': '69.8', 'Capture Rate - Total (%)': '47.6'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '6.8', 'Capture Rate - Paper (%)': '21.1', 'Capture Rate - MGP (%)': '24.6', 'Capture Rate - Total (%)': '22.7'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '13.3', 'Capture Rate - Paper (%)': '37.9', 'Capture Rate - MGP (%)': '53.2', 'Capture Rate - Total (%)': '44.5'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '10.6', 'Capture Rate - Paper (%)': '31.1', 'Capture Rate - MGP (%)': '41.1', 'Capture Rate - Total (%)': '35.5'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '10.9', 'Capture Rate - Paper (%)': '30.5', 'Capture Rate - MGP (%)': '44.5', 'Capture Rate - Total (%)': '36.6'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '12.0', 'Capture Rate - Paper (%)': '30.7', 'Capture Rate - MGP (%)': '52.4', 'Capture Rate - Total (%)': '40.2'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '14.0', 'Capture Rate - Paper (%)': '37.7', 'Capture Rate - MGP (%)': '44.1', 'Capture Rate - Total (%)': '40.5'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '13.6', 'Capture Rate - Paper (%)': '36.0', 'Capture Rate - MGP (%)': '58.1', 'Capture Rate - Total (%)': '45.7'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '20.5', 'Capture Rate - Paper (%)': '49.7', 'Capture Rate - MGP (%)': '78.7', 'Capture Rate - Total (%)': '59.6'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '9.7', 'Capture Rate - Paper (%)': '23.1', 'Capture Rate - MGP (%)': '41.1', 'Capture Rate - Total (%)': '30.5'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '18.0', 'Capture Rate - Paper (%)': '43.1', 'Capture Rate - MGP (%)': '64.1', 'Capture Rate - Total (%)': '51.1'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '13.9', 'Capture Rate - Paper (%)': '35.6', 'Capture Rate - MGP (%)': '53.3', 'Capture Rate - Total (%)': '42.3'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '12', 'Diversion Rate (%)': '16.2', 'Capture Rate - Paper (%)': '35.3', 'Capture Rate - MGP (%)': '72.5', 'Capture Rate - Total (%)': '49.4'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '6.6', 'Capture Rate - Paper (%)': '17.8', 'Capture Rate - MGP (%)': '25.4', 'Capture Rate - Total (%)': '21.0'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '12.5', 'Capture Rate - Paper (%)': '29.5', 'Capture Rate - MGP (%)': '53.7', 'Capture Rate - Total (%)': '39.9'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '9.8', 'Capture Rate - Paper (%)': '25.4', 'Capture Rate - MGP (%)': '38.9', 'Capture Rate - Total (%)': '31.2'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '10.9', 'Capture Rate - Paper (%)': '26.9', 'Capture Rate - MGP (%)': '45.3', 'Capture Rate - Total (%)': '34.8'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '11.7', 'Capture Rate - Paper (%)': '25.7', 'Capture Rate - MGP (%)': '52.9', 'Capture Rate - Total (%)': '37.4'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '12.2', 'Capture Rate - Paper (%)': '34.6', 'Capture Rate - MGP (%)': '45.3', 'Capture Rate - Total (%)': '39.2'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '13.5', 'Capture Rate - Paper (%)': '31.3', 'Capture Rate - MGP (%)': '59.3', 'Capture Rate - Total (%)': '43.3'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '20.0', 'Capture Rate - Paper (%)': '41.4', 'Capture Rate - MGP (%)': '78.1', 'Capture Rate - Total (%)': '53.3'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '9.7', 'Capture Rate - Paper (%)': '23.4', 'Capture Rate - MGP (%)': '37.0', 'Capture Rate - Total (%)': '29.6'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '18.3', 'Capture Rate - Paper (%)': '43.0', 'Capture Rate - MGP (%)': '62.0', 'Capture Rate - Total (%)': '50.6'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '14.0', 'Capture Rate - Paper (%)': '34.9', 'Capture Rate - MGP (%)': '49.5', 'Capture Rate - Total (%)': '40.7'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2017', 'Fiscal Month': '01', 'Diversion Rate (%)': '16.3', 'Capture Rate - Paper (%)': '33.9', 'Capture Rate - MGP (%)': '68.4', 'Capture Rate - Total (%)': '47.6'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '6.5', 'Capture Rate - Paper (%)': '17.2', 'Capture Rate - MGP (%)': '25.7', 'Capture Rate - Total (%)': '20.8'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '12.9', 'Capture Rate - Paper (%)': '32.3', 'Capture Rate - MGP (%)': '53.1', 'Capture Rate - Total (%)': '41.2'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '8.8', 'Capture Rate - Paper (%)': '22.2', 'Capture Rate - MGP (%)': '36.4', 'Capture Rate - Total (%)': '28.3'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '10.9', 'Capture Rate - Paper (%)': '26.6', 'Capture Rate - MGP (%)': '45.9', 'Capture Rate - Total (%)': '34.9'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '11.8', 'Capture Rate - Paper (%)': '25.3', 'Capture Rate - MGP (%)': '54.0', 'Capture Rate - Total (%)': '37.6'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '11.9', 'Capture Rate - Paper (%)': '32.7', 'Capture Rate - MGP (%)': '44.8', 'Capture Rate - Total (%)': '37.9'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '13.6', 'Capture Rate - Paper (%)': '30.5', 'Capture Rate - MGP (%)': '60.7', 'Capture Rate - Total (%)': '43.4'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '20.1', 'Capture Rate - Paper (%)': '41.4', 'Capture Rate - MGP (%)': '79.4', 'Capture Rate - Total (%)': '53.7'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '9.6', 'Capture Rate - Paper (%)': '23.2', 'Capture Rate - MGP (%)': '36.9', 'Capture Rate - Total (%)': '29.5'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '18.3', 'Capture Rate - Paper (%)': '42.2', 'Capture Rate - MGP (%)': '62.7', 'Capture Rate - Total (%)': '50.3'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '13.9', 'Capture Rate - Paper (%)': '33.8', 'Capture Rate - MGP (%)': '50.7', 'Capture Rate - Total (%)': '40.5'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2017', 'Fiscal Month': '02', 'Diversion Rate (%)': '16.2', 'Capture Rate - Paper (%)': '33.6', 'Capture Rate - MGP (%)': '68.0', 'Capture Rate - Total (%)': '47.3'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '6.7', 'Capture Rate - Paper (%)': '19.5', 'Capture Rate - MGP (%)': '25.5', 'Capture Rate - Total (%)': '22.1'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '12.8', 'Capture Rate - Paper (%)': '33.6', 'Capture Rate - MGP (%)': '53.0', 'Capture Rate - Total (%)': '42.1'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '9.5', 'Capture Rate - Paper (%)': '27.6', 'Capture Rate - MGP (%)': '35.9', 'Capture Rate - Total (%)': '31.2'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '10.8', 'Capture Rate - Paper (%)': '27.8', 'Capture Rate - MGP (%)': '45.4', 'Capture Rate - Total (%)': '35.5'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '11.7', 'Capture Rate - Paper (%)': '27.1', 'Capture Rate - MGP (%)': '53.3', 'Capture Rate - Total (%)': '38.5'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '14.3', 'Capture Rate - Paper (%)': '36.0', 'Capture Rate - MGP (%)': '44.6', 'Capture Rate - Total (%)': '39.7'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '13.5', 'Capture Rate - Paper (%)': '32.6', 'Capture Rate - MGP (%)': '59.9', 'Capture Rate - Total (%)': '44.5'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '20.3', 'Capture Rate - Paper (%)': '46.0', 'Capture Rate - MGP (%)': '80.0', 'Capture Rate - Total (%)': '56.8'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '9.7', 'Capture Rate - Paper (%)': '26.5', 'Capture Rate - MGP (%)': '39.6', 'Capture Rate - Total (%)': '32.5'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '17.9', 'Capture Rate - Paper (%)': '41.8', 'Capture Rate - MGP (%)': '74.0', 'Capture Rate - Total (%)': '52.8'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '13.7', 'Capture Rate - Paper (%)': '32.0', 'Capture Rate - MGP (%)': '63.7', 'Capture Rate - Total (%)': '42.8'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2017', 'Fiscal Month': '03', 'Diversion Rate (%)': '16.5', 'Capture Rate - Paper (%)': '34.1', 'Capture Rate - MGP (%)': '84.5', 'Capture Rate - Total (%)': '51.3'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '6.3', 'Capture Rate - Paper (%)': '18.0', 'Capture Rate - MGP (%)': '24.6', 'Capture Rate - Total (%)': '20.9'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '12.8', 'Capture Rate - Paper (%)': '31.7', 'Capture Rate - MGP (%)': '55.2', 'Capture Rate - Total (%)': '41.9'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '8.5', 'Capture Rate - Paper (%)': '23.1', 'Capture Rate - MGP (%)': '34.6', 'Capture Rate - Total (%)': '28.1'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '10.7', 'Capture Rate - Paper (%)': '26.8', 'Capture Rate - MGP (%)': '45.5', 'Capture Rate - Total (%)': '35.0'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '11.4', 'Capture Rate - Paper (%)': '26.1', 'Capture Rate - MGP (%)': '52.1', 'Capture Rate - Total (%)': '37.4'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '13.6', 'Capture Rate - Paper (%)': '32.6', 'Capture Rate - MGP (%)': '43.2', 'Capture Rate - Total (%)': '37.2'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '13.2', 'Capture Rate - Paper (%)': '31.2', 'Capture Rate - MGP (%)': '59.4', 'Capture Rate - Total (%)': '43.5'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '19.8', 'Capture Rate - Paper (%)': '42.8', 'Capture Rate - MGP (%)': '80.7', 'Capture Rate - Total (%)': '54.8'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '9.2', 'Capture Rate - Paper (%)': '24.6', 'Capture Rate - MGP (%)': '38.3', 'Capture Rate - Total (%)': '30.8'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '18.0', 'Capture Rate - Paper (%)': '41.7', 'Capture Rate - MGP (%)': '73.3', 'Capture Rate - Total (%)': '52.5'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '13.6', 'Capture Rate - Paper (%)': '31.8', 'Capture Rate - MGP (%)': '62.9', 'Capture Rate - Total (%)': '42.4'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2017', 'Fiscal Month': '04', 'Diversion Rate (%)': '15.8', 'Capture Rate - Paper (%)': '33.0', 'Capture Rate - MGP (%)': '80.5', 'Capture Rate - Total (%)': '49.2'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '6.4', 'Capture Rate - Paper (%)': '17.9', 'Capture Rate - MGP (%)': '24.8', 'Capture Rate - Total (%)': '20.9'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '12.4', 'Capture Rate - Paper (%)': '32.2', 'Capture Rate - MGP (%)': '51.8', 'Capture Rate - Total (%)': '40.8'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '8.5', 'Capture Rate - Paper (%)': '23.4', 'Capture Rate - MGP (%)': '33.6', 'Capture Rate - Total (%)': '27.8'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '10.7', 'Capture Rate - Paper (%)': '27.1', 'Capture Rate - MGP (%)': '45.4', 'Capture Rate - Total (%)': '35.1'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '11.6', 'Capture Rate - Paper (%)': '27.4', 'Capture Rate - MGP (%)': '52.1', 'Capture Rate - Total (%)': '38.2'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '13.8', 'Capture Rate - Paper (%)': '32.8', 'Capture Rate - MGP (%)': '44.0', 'Capture Rate - Total (%)': '37.7'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '13.8', 'Capture Rate - Paper (%)': '33.1', 'Capture Rate - MGP (%)': '61.0', 'Capture Rate - Total (%)': '45.3'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '21.2', 'Capture Rate - Paper (%)': '44.8', 'Capture Rate - MGP (%)': '81.6', 'Capture Rate - Total (%)': '56.5'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '9.5', 'Capture Rate - Paper (%)': '25.5', 'Capture Rate - MGP (%)': '38.3', 'Capture Rate - Total (%)': '31.3'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '19.1', 'Capture Rate - Paper (%)': '42.8', 'Capture Rate - MGP (%)': '73.0', 'Capture Rate - Total (%)': '53.1'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '14.6', 'Capture Rate - Paper (%)': '33.2', 'Capture Rate - MGP (%)': '63.8', 'Capture Rate - Total (%)': '43.7'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2017', 'Fiscal Month': '05', 'Diversion Rate (%)': '17.6', 'Capture Rate - Paper (%)': '35.0', 'Capture Rate - MGP (%)': '82.2', 'Capture Rate - Total (%)': '51.1'}
# {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '6.9', 'Capture Rate - Paper (%)': '21.2', 'Capture Rate - MGP (%)': '23.5', 'Capture Rate - Total (%)': '22.2'}
# {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '13.7', 'Capture Rate - Paper (%)': '36.8', 'Capture Rate - MGP (%)': '53.1', 'Capture Rate - Total (%)': '44.2'}
# {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '9.5', 'Capture Rate - Paper (%)': '28.4', 'Capture Rate - MGP (%)': '33.4', 'Capture Rate - Total (%)': '30.7'}
# {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '11.4', 'Capture Rate - Paper (%)': '31.9', 'Capture Rate - MGP (%)': '42.5', 'Capture Rate - Total (%)': '36.7'}
# {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '12.3', 'Capture Rate - Paper (%)': '32.1', 'Capture Rate - MGP (%)': '48.9', 'Capture Rate - Total (%)': '39.7'}
# {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '13.9', 'Capture Rate - Paper (%)': '36.7', 'Capture Rate - MGP (%)': '42.3', 'Capture Rate - Total (%)': '39.2'}
# {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '14.4', 'Capture Rate - Paper (%)': '38.2', 'Capture Rate - MGP (%)': '56.1', 'Capture Rate - Total (%)': '46.2'}
# {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '21.8', 'Capture Rate - Paper (%)': '44.2', 'Capture Rate - MGP (%)': '76.6', 'Capture Rate - Total (%)': '54.3'}
# {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '10.2', 'Capture Rate - Paper (%)': '25.5', 'Capture Rate - MGP (%)': '42.2', 'Capture Rate - Total (%)': '32.4'}
# {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '20.0', 'Capture Rate - Paper (%)': '47.1', 'Capture Rate - MGP (%)': '63.8', 'Capture Rate - Total (%)': '53.2'}
# {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '15.3', 'Capture Rate - Paper (%)': '36.3', 'Capture Rate - MGP (%)': '54.1', 'Capture Rate - Total (%)': '42.8'}
# {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2017', 'Fiscal Month': '06', 'Diversion Rate (%)': '17.7', 'Capture Rate - Paper (%)': '37.2', 'Capture Rate - MGP (%)': '71.2', 'Capture Rate - Total (%)': '49.6'}
# ...
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '02', 'Diversion Rate (%)': '19.9', 'Capture Rate - Paper (%)': '38.7', 'Capture Rate - MGP (%)': '73.5', 'Capture Rate - Total (%)': '51.1'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '02', 'Diversion Rate (%)': '18.6', 'Capture Rate - Paper (%)': '43.4', 'Capture Rate - MGP (%)': '72.9', 'Capture Rate - Total (%)': '53.9'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '02', 'Diversion Rate (%)': '19.9', 'Capture Rate - Paper (%)': '46.0', 'Capture Rate - MGP (%)': '79.3', 'Capture Rate - Total (%)': '57.8'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '03', 'Diversion Rate (%)': '19.8', 'Capture Rate - Paper (%)': '37.8', 'Capture Rate - MGP (%)': '81.4', 'Capture Rate - Total (%)': '51.5'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '03', 'Diversion Rate (%)': '19.3', 'Capture Rate - Paper (%)': '41.8', 'Capture Rate - MGP (%)': '81.2', 'Capture Rate - Total (%)': '54.2'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '03', 'Diversion Rate (%)': '20.3', 'Capture Rate - Paper (%)': '44.2', 'Capture Rate - MGP (%)': '87.5', 'Capture Rate - Total (%)': '57.8'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '04', 'Diversion Rate (%)': '19.7', 'Capture Rate - Paper (%)': '38.1', 'Capture Rate - MGP (%)': '79.8', 'Capture Rate - Total (%)': '51.2'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '04', 'Diversion Rate (%)': '19.4', 'Capture Rate - Paper (%)': '41.8', 'Capture Rate - MGP (%)': '78.2', 'Capture Rate - Total (%)': '53.2'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '04', 'Diversion Rate (%)': '20.6', 'Capture Rate - Paper (%)': '44.1', 'Capture Rate - MGP (%)': '88.7', 'Capture Rate - Total (%)': '58.1'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '05', 'Diversion Rate (%)': '22.9', 'Capture Rate - Paper (%)': '38.5', 'Capture Rate - MGP (%)': '75.3', 'Capture Rate - Total (%)': '50.1'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '05', 'Diversion Rate (%)': '21.8', 'Capture Rate - Paper (%)': '42.4', 'Capture Rate - MGP (%)': '74.6', 'Capture Rate - Total (%)': '52.5'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '05', 'Diversion Rate (%)': '24.6', 'Capture Rate - Paper (%)': '44.3', 'Capture Rate - MGP (%)': '81.3', 'Capture Rate - Total (%)': '56.0'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '06', 'Diversion Rate (%)': '22.2', 'Capture Rate - Paper (%)': '40.4', 'Capture Rate - MGP (%)': '71.1', 'Capture Rate - Total (%)': '50.2'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '06', 'Diversion Rate (%)': '21.7', 'Capture Rate - Paper (%)': '45.4', 'Capture Rate - MGP (%)': '71.0', 'Capture Rate - Total (%)': '53.6'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '06', 'Diversion Rate (%)': '23.0', 'Capture Rate - Paper (%)': '50.3', 'Capture Rate - MGP (%)': '74.6', 'Capture Rate - Total (%)': '58.1'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '07', 'Diversion Rate (%)': '21.7', 'Capture Rate - Paper (%)': '37.9', 'Capture Rate - MGP (%)': '77.1', 'Capture Rate - Total (%)': '50.4'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '07', 'Diversion Rate (%)': '23.2', 'Capture Rate - Paper (%)': '43.3', 'Capture Rate - MGP (%)': '76.6', 'Capture Rate - Total (%)': '54.0'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '07', 'Diversion Rate (%)': '24.4', 'Capture Rate - Paper (%)': '47.7', 'Capture Rate - MGP (%)': '83.1', 'Capture Rate - Total (%)': '59.0'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '08', 'Diversion Rate (%)': '19.4', 'Capture Rate - Paper (%)': '37.3', 'Capture Rate - MGP (%)': '71.0', 'Capture Rate - Total (%)': '48.1'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '08', 'Diversion Rate (%)': '21.2', 'Capture Rate - Paper (%)': '42.4', 'Capture Rate - MGP (%)': '74.3', 'Capture Rate - Total (%)': '52.6'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '08', 'Diversion Rate (%)': '21.6', 'Capture Rate - Paper (%)': '44.2', 'Capture Rate - MGP (%)': '78.0', 'Capture Rate - Total (%)': '55.0'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '09', 'Diversion Rate (%)': '19.3', 'Capture Rate - Paper (%)': '37.3', 'Capture Rate - MGP (%)': '68.3', 'Capture Rate - Total (%)': '47.2'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '09', 'Diversion Rate (%)': '20.2', 'Capture Rate - Paper (%)': '42.2', 'Capture Rate - MGP (%)': '66.5', 'Capture Rate - Total (%)': '50.0'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '09', 'Diversion Rate (%)': '21.3', 'Capture Rate - Paper (%)': '45.2', 'Capture Rate - MGP (%)': '73.1', 'Capture Rate - Total (%)': '54.1'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '10', 'Diversion Rate (%)': '19.9', 'Capture Rate - Paper (%)': '48.7', 'Capture Rate - MGP (%)': '81.1', 'Capture Rate - Total (%)': '60.2'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '10', 'Diversion Rate (%)': '19.7', 'Capture Rate - Paper (%)': '53.6', 'Capture Rate - MGP (%)': '82.5', 'Capture Rate - Total (%)': '63.9'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '10', 'Diversion Rate (%)': '19.9', 'Capture Rate - Paper (%)': '55.8', 'Capture Rate - MGP (%)': '86.6', 'Capture Rate - Total (%)': '66.7'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '11', 'Diversion Rate (%)': '19.5', 'Capture Rate - Paper (%)': '43.5', 'Capture Rate - MGP (%)': '76.4', 'Capture Rate - Total (%)': '55.2'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '11', 'Diversion Rate (%)': '17.9', 'Capture Rate - Paper (%)': '48.2', 'Capture Rate - MGP (%)': '75.8', 'Capture Rate - Total (%)': '58.1'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '11', 'Diversion Rate (%)': '18.6', 'Capture Rate - Paper (%)': '50.1', 'Capture Rate - MGP (%)': '84.0', 'Capture Rate - Total (%)': '62.1'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2018', 'Fiscal Month': '12', 'Diversion Rate (%)': '20.7', 'Capture Rate - Paper (%)': '47.8', 'Capture Rate - MGP (%)': '82.8', 'Capture Rate - Total (%)': '60.2'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2018', 'Fiscal Month': '12', 'Diversion Rate (%)': '19.1', 'Capture Rate - Paper (%)': '51.0', 'Capture Rate - MGP (%)': '84.8', 'Capture Rate - Total (%)': '63.0'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2018', 'Fiscal Month': '12', 'Diversion Rate (%)': '19.7', 'Capture Rate - Paper (%)': '53.3', 'Capture Rate - MGP (%)': '89.6', 'Capture Rate - Total (%)': '66.2'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '01', 'Diversion Rate (%)': '19.8', 'Capture Rate - Paper (%)': '39.8', 'Capture Rate - MGP (%)': '71.9', 'Capture Rate - Total (%)': '51.2'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '01', 'Diversion Rate (%)': '18.7', 'Capture Rate - Paper (%)': '42.9', 'Capture Rate - MGP (%)': '73.3', 'Capture Rate - Total (%)': '53.7'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '01', 'Diversion Rate (%)': '19.8', 'Capture Rate - Paper (%)': '45.3', 'Capture Rate - MGP (%)': '80.1', 'Capture Rate - Total (%)': '57.6'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '02', 'Diversion Rate (%)': '19.8', 'Capture Rate - Paper (%)': '38.7', 'Capture Rate - MGP (%)': '69.4', 'Capture Rate - Total (%)': '49.6'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '02', 'Diversion Rate (%)': '17.9', 'Capture Rate - Paper (%)': '42.6', 'Capture Rate - MGP (%)': '67.6', 'Capture Rate - Total (%)': '51.5'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '02', 'Diversion Rate (%)': '19.3', 'Capture Rate - Paper (%)': '45.4', 'Capture Rate - MGP (%)': '76.1', 'Capture Rate - Total (%)': '56.3'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '03', 'Diversion Rate (%)': '20.4', 'Capture Rate - Paper (%)': '38.9', 'Capture Rate - MGP (%)': '80.5', 'Capture Rate - Total (%)': '52.0'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '03', 'Diversion Rate (%)': '19.5', 'Capture Rate - Paper (%)': '42.3', 'Capture Rate - MGP (%)': '79.8', 'Capture Rate - Total (%)': '54.1'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '03', 'Diversion Rate (%)': '20.7', 'Capture Rate - Paper (%)': '45.9', 'Capture Rate - MGP (%)': '87.2', 'Capture Rate - Total (%)': '58.9'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '04', 'Diversion Rate (%)': '20.0', 'Capture Rate - Paper (%)': '37.7', 'Capture Rate - MGP (%)': '79.0', 'Capture Rate - Total (%)': '50.7'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '04', 'Diversion Rate (%)': '19.3', 'Capture Rate - Paper (%)': '41.9', 'Capture Rate - MGP (%)': '77.3', 'Capture Rate - Total (%)': '53.0'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '04', 'Diversion Rate (%)': '20.2', 'Capture Rate - Paper (%)': '44.4', 'Capture Rate - MGP (%)': '85.1', 'Capture Rate - Total (%)': '57.2'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '05', 'Diversion Rate (%)': '27.1', 'Capture Rate - Paper (%)': '37.0', 'Capture Rate - MGP (%)': '73.1', 'Capture Rate - Total (%)': '48.4'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '05', 'Diversion Rate (%)': '27.3', 'Capture Rate - Paper (%)': '41.8', 'Capture Rate - MGP (%)': '70.9', 'Capture Rate - Total (%)': '51.0'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '05', 'Diversion Rate (%)': '29.5', 'Capture Rate - Paper (%)': '43.1', 'Capture Rate - MGP (%)': '75.4', 'Capture Rate - Total (%)': '53.3'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '06', 'Diversion Rate (%)': '22.2', 'Capture Rate - Paper (%)': '39.5', 'Capture Rate - MGP (%)': '70.3', 'Capture Rate - Total (%)': '49.3'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '06', 'Diversion Rate (%)': '20.7', 'Capture Rate - Paper (%)': '43.4', 'Capture Rate - MGP (%)': '68.2', 'Capture Rate - Total (%)': '51.3'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '06', 'Diversion Rate (%)': '22.3', 'Capture Rate - Paper (%)': '48.7', 'Capture Rate - MGP (%)': '72.8', 'Capture Rate - Total (%)': '56.4'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '07', 'Diversion Rate (%)': '21.8', 'Capture Rate - Paper (%)': '39.7', 'Capture Rate - MGP (%)': '79.8', 'Capture Rate - Total (%)': '52.5'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '07', 'Diversion Rate (%)': '22.6', 'Capture Rate - Paper (%)': '44.2', 'Capture Rate - MGP (%)': '76.8', 'Capture Rate - Total (%)': '54.6'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '07', 'Diversion Rate (%)': '23.4', 'Capture Rate - Paper (%)': '46.4', 'Capture Rate - MGP (%)': '82.4', 'Capture Rate - Total (%)': '57.9'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '08', 'Diversion Rate (%)': '19.6', 'Capture Rate - Paper (%)': '36.1', 'Capture Rate - MGP (%)': '76.1', 'Capture Rate - Total (%)': '48.9'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '08', 'Diversion Rate (%)': '20.6', 'Capture Rate - Paper (%)': '40.7', 'Capture Rate - MGP (%)': '73.7', 'Capture Rate - Total (%)': '51.2'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '08', 'Diversion Rate (%)': '21.6', 'Capture Rate - Paper (%)': '43.0', 'Capture Rate - MGP (%)': '81.1', 'Capture Rate - Total (%)': '55.2'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '09', 'Diversion Rate (%)': '19.7', 'Capture Rate - Paper (%)': '34.9', 'Capture Rate - MGP (%)': '74.9', 'Capture Rate - Total (%)': '47.7'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '09', 'Diversion Rate (%)': '20.2', 'Capture Rate - Paper (%)': '39.4', 'Capture Rate - MGP (%)': '72.6', 'Capture Rate - Total (%)': '50.0'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '09', 'Diversion Rate (%)': '20.6', 'Capture Rate - Paper (%)': '40.5', 'Capture Rate - MGP (%)': '77.8', 'Capture Rate - Total (%)': '52.4'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '10', 'Diversion Rate (%)': '20.2', 'Capture Rate - Paper (%)': '45.3', 'Capture Rate - MGP (%)': '85.6', 'Capture Rate - Total (%)': '59.6'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '10', 'Diversion Rate (%)': '19.3', 'Capture Rate - Paper (%)': '50.6', 'Capture Rate - MGP (%)': '86.6', 'Capture Rate - Total (%)': '63.4'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '10', 'Diversion Rate (%)': '19.5', 'Capture Rate - Paper (%)': '52.1', 'Capture Rate - MGP (%)': '90.6', 'Capture Rate - Total (%)': '65.8'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '11', 'Diversion Rate (%)': '20.0', 'Capture Rate - Paper (%)': '42.8', 'Capture Rate - MGP (%)': '81.2', 'Capture Rate - Total (%)': '56.5'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '11', 'Diversion Rate (%)': '17.9', 'Capture Rate - Paper (%)': '46.9', 'Capture Rate - MGP (%)': '77.9', 'Capture Rate - Total (%)': '57.9'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '11', 'Diversion Rate (%)': '18.9', 'Capture Rate - Paper (%)': '50.2', 'Capture Rate - MGP (%)': '87.4', 'Capture Rate - Total (%)': '63.4'}
# {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2019', 'Fiscal Month': '12', 'Diversion Rate (%)': '21.5', 'Capture Rate - Paper (%)': '48.2', 'Capture Rate - MGP (%)': '90.4', 'Capture Rate - Total (%)': '63.2'}
# {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2019', 'Fiscal Month': '12', 'Diversion Rate (%)': '19.3', 'Capture Rate - Paper (%)': '52.8', 'Capture Rate - MGP (%)': '84.1', 'Capture Rate - Total (%)': '63.9'}
# {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2019', 'Fiscal Month': '12', 'Diversion Rate (%)': '20.5', 'Capture Rate - Paper (%)': '54.8', 'Capture Rate - MGP (%)': '95.4', 'Capture Rate - Total (%)': '69.2'}

# %% [markdown]
# ### Now that we have sorted the data by each borough from 2016 to 2019, we will now do an analysis. After looking through the data, these are the questions I would like to answer:
#
# * What is the yearly average diversion rate per borough?
# * What is the percentage of paper versus MGP capture efficiency by borough
# * What is the monthly trend, by borough, for total capture rate?
# * Which borough is top-performing by average total capture rate?
# * What is the improvement or decline in diversion rate per borough?
# * Which borough had the highest average capture rate in a given year?

# %% [markdown]
# ### To begin, we will go through several steps to calculate the average diversion rate per borough, which will include first creating a list of each borough from sorted_records, then from that list, create seperate lists for each year. Lastly, we then create a dictionary for each borough from 2016 to 2019 on the average diversion rate (per year).

# %%
def filter_by_borough(records, borough_input):
    borough_input = borough_input.lower()
    return [row for row in records if borough_input in row['Borough'].lower()]


bronx_list = filter_by_borough(sorted_records, "Bronx")
brooklyn_list = filter_by_borough(sorted_records, "Brooklyn")
manhattan_list = filter_by_borough(sorted_records, "Manhattan")
queens_list = filter_by_borough(sorted_records, "Queens")
staten_island_list = filter_by_borough(sorted_records, "Staten Island")


print(bronx_list)
print(brooklyn_list)
print(manhattan_list)
print(queens_list)
print(staten_island_list)
# Out:
# [{'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '5.9', 'Capture Rate - Paper (%)': '17.1', 'Capture Rate - MGP (%)': '21.6', 'Capture Rate - Total (%)': '19.0'}, {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '11.4', 'Capture Rate - Paper (%)': '30.0', 'Capture Rate - MGP (%)': '45.3', 'Capture Rate - Total (%)': '36.5'}, {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '8.5', 'Capture Rate - Paper (%)': '23.8', 'Capture Rate - MGP (%)': '31.5', 'Capture Rate - Total (%)': '27.1'}, {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '9.8', 'Capture Rate - Paper (%)': '26.3', 'Capture Rate - MGP (%)': '38.0', 'Capture Rate - Total (%)': '31.3'}, {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '10.9', 'Capture Rate - Paper (%)': '26.2', 'Capture Rate - MGP (%)': '46.3', 'Capture Rate - Total (%)': '34.9'}, {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '11.0', 'Capture Rate - Paper (%)': '34.1', 'Capture Rate - MGP (%)': '36.7', 'Capture Rate - Total (%)': '35.2'}, {'Borough': 'Bronx', 'District': 'BX07', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '12.7', 'Capture Rate - Paper (%)': '32.1', 'Capture Rate - MGP (%)': '52.0', 'Capture Rate - Total (%)': '40.7'}, {'Borough': 'Bronx', 'District': 'BX08', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '19.6', 'Capture Rate - Paper (%)': '41.8', 'Capture Rate - MGP (%)': '73.4', 'Capture Rate - Total (%)': '52.0'}, {'Borough': 'Bronx', 'District': 'BX09', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '8.8', 'Capture Rate - Paper (%)': '22.6', 'Capture Rate - MGP (%)': '32.1', 'Capture Rate - Total (%)': '26.9'}, {'Borough': 'Bronx', 'District': 'BX10', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '17.7', 'Capture Rate - Paper (%)': '41.9', 'Capture Rate - MGP (%)': '59.4', 'Capture Rate - Total (%)': '48.8'}, {'Borough': 'Bronx', 'District': 'BX11', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '13.7', 'Capture Rate - Paper (%)': '35.0', 'Capture Rate - MGP (%)': '47.5', 'Capture Rate - Total (%)': '40.0'}, {'Borough': 'Bronx', 'District': 'BX12', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '15.5', 'Capture Rate - Paper (%)': '33.6', 'Capture Rate - MGP (%)': '62.9', 'Capture Rate - Total (%)': '45.2'}, {'Borough': 'Bronx', 'District': 'BX01', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '6.3', 'Capture Rate - Paper (%)': '17.1', 'Capture Rate - MGP (%)': '23.9', 'Capture Rate - Total (%)': '20.0'}, {'Borough': 'Bronx', 'District': 'BX02', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '11.2', 'Capture Rate - Paper (%)': '28.2', 'Capture Rate - MGP (%)': '46.2', 'Capture Rate - Total (%)': '35.9'}, {'Borough': 'Bronx', 'District': 'BX03', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '8.3', 'Capture Rate - Paper (%)': '21.5', 'Capture Rate - MGP (%)': '33.5', 'Capture Rate - Total (%)': '26.7'}, {'Borough': 'Bronx', 'District': 'BX04', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '9.9', 'Capture Rate - Paper (%)': '25.1', 'Capture Rate - MGP (%)': '40.5', 'Capture Rate - Total (%)': '31.7'}, {'Borough': 'Bronx', 'District': 'BX05', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '11.2', 'Capture Rate - Paper (%)': '25.8', 'Capture Rate - MGP (%)': '48.9', 'Capture Rate - Total (%)': '35.7'}, {'Borough': 'Bronx', 'District': 'BX06', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '11.1', 'Capture Rate - Paper (%)': '32.9', 'Capture Rate - MGP (%)': '38.8', 'Capture Rate - Total (%)': ' ...
# [{'Borough': 'Brooklyn North', 'District': 'BKN01', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '14.7', 'Capture Rate - Paper (%)': '44.0', 'Capture Rate - MGP (%)': '43.2', 'Capture Rate - Total (%)': '43.6'}, {'Borough': 'Brooklyn North', 'District': 'BKN02', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '16.5', 'Capture Rate - Paper (%)': '30.2', 'Capture Rate - MGP (%)': '49.8', 'Capture Rate - Total (%)': '36.0'}, {'Borough': 'Brooklyn North', 'District': 'BKN03', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '10.1', 'Capture Rate - Paper (%)': '29.0', 'Capture Rate - MGP (%)': '32.8', 'Capture Rate - Total (%)': '30.8'}, {'Borough': 'Brooklyn North', 'District': 'BKN04', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '12.4', 'Capture Rate - Paper (%)': '30.6', 'Capture Rate - MGP (%)': '46.4', 'Capture Rate - Total (%)': '37.8'}, {'Borough': 'Brooklyn North', 'District': 'BKN05', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '9.1', 'Capture Rate - Paper (%)': '23.5', 'Capture Rate - MGP (%)': '33.0', 'Capture Rate - Total (%)': '27.9'}, {'Borough': 'Brooklyn North', 'District': 'BKN08', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '13.8', 'Capture Rate - Paper (%)': '39.7', 'Capture Rate - MGP (%)': '45.0', 'Capture Rate - Total (%)': '42.1'}, {'Borough': 'Brooklyn North', 'District': 'BKN09', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '11.0', 'Capture Rate - Paper (%)': '27.7', 'Capture Rate - MGP (%)': '38.8', 'Capture Rate - Total (%)': '32.1'}, {'Borough': 'Brooklyn North', 'District': 'BKN16', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '7.7', 'Capture Rate - Paper (%)': '20.6', 'Capture Rate - MGP (%)': '27.0', 'Capture Rate - Total (%)': '23.5'}, {'Borough': 'Brooklyn North', 'District': 'BKN17', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '12.8', 'Capture Rate - Paper (%)': '27.8', 'Capture Rate - MGP (%)': '51.9', 'Capture Rate - Total (%)': '37.4'}, {'Borough': 'Brooklyn North', 'District': 'BKN01', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '15.0', 'Capture Rate - Paper (%)': '46.6', 'Capture Rate - MGP (%)': '42.4', 'Capture Rate - Total (%)': '44.7'}, {'Borough': 'Brooklyn North', 'District': 'BKN02', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '16.6', 'Capture Rate - Paper (%)': '30.8', 'Capture Rate - MGP (%)': '49.1', 'Capture Rate - Total (%)': '36.2'}, {'Borough': 'Brooklyn North', 'District': 'BKN03', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '10.3', 'Capture Rate - Paper (%)': '29.6', 'Capture Rate - MGP (%)': '33.5', 'Capture Rate - Total (%)': '31.4'}, {'Borough': 'Brooklyn North', 'District': 'BKN04', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '12.6', 'Capture Rate - Paper (%)': '30.5', 'Capture Rate - MGP (%)': '48.1', 'Capture Rate - Total (%)': '38.5'}, {'Borough': 'Brooklyn North', 'District': 'BKN05', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '9.3', 'Capture Rate - Paper (%)': '23.3', 'Capture Rate - MGP (%)': '34.4', 'Capture Rate - Total (%)': '28.4'}, {'Borough': 'Brooklyn North', 'District': 'BKN08', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '14.3', 'Capture Rate - Paper (%)': '41.2', 'Capture Rate - MGP (%)': '46.7', 'Capture Rate - Total (%)': '43.7'}, {'Borough': 'Brooklyn North', 'District': 'BKN09', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '11.6', 'Capture Rate - Paper (%)': '30.9', 'Capture Rate - MGP (%)': '38.1', 'Capture Rate - Total (%)': '33.8'}, {'Borough': 'Brooklyn North', 'District': 'BKN16', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '7.9', 'Capture Rate - Paper (%)': '20.8', 'Capture Rate - MGP (%)': '27.9', 'Capture Rate - Total (%)': '24.0'}, {'Borough': 'Brooklyn North', 'District':  ...
# [{'Borough': 'Manhattan', 'District': 'MN01', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '25.1', 'Capture Rate - Paper (%)': '43.3', 'Capture Rate - MGP (%)': '60.4', 'Capture Rate - Total (%)': '47.9'}, {'Borough': 'Manhattan', 'District': 'MN02', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '22.0', 'Capture Rate - Paper (%)': '34.6', 'Capture Rate - MGP (%)': '65.0', 'Capture Rate - Total (%)': '42.7'}, {'Borough': 'Manhattan', 'District': 'MN03', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '12.6', 'Capture Rate - Paper (%)': '39.9', 'Capture Rate - MGP (%)': '39.5', 'Capture Rate - Total (%)': '39.7'}, {'Borough': 'Manhattan', 'District': 'MN04', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '20.8', 'Capture Rate - Paper (%)': '30.9', 'Capture Rate - MGP (%)': '66.1', 'Capture Rate - Total (%)': '40.4'}, {'Borough': 'Manhattan', 'District': 'MN05', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '17.1', 'Capture Rate - Paper (%)': '27.8', 'Capture Rate - MGP (%)': '47.7', 'Capture Rate - Total (%)': '33.2'}, {'Borough': 'Manhattan', 'District': 'MN06', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '20.7', 'Capture Rate - Paper (%)': '32.2', 'Capture Rate - MGP (%)': '62.4', 'Capture Rate - Total (%)': '40.3'}, {'Borough': 'Manhattan', 'District': 'MN07', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '23.9', 'Capture Rate - Paper (%)': '39.1', 'Capture Rate - MGP (%)': '64.4', 'Capture Rate - Total (%)': '45.9'}, {'Borough': 'Manhattan', 'District': 'MN08', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '23.9', 'Capture Rate - Paper (%)': '39.6', 'Capture Rate - MGP (%)': '64.0', 'Capture Rate - Total (%)': '46.1'}, {'Borough': 'Manhattan', 'District': 'MN09', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '15.0', 'Capture Rate - Paper (%)': '51.3', 'Capture Rate - MGP (%)': '43.7', 'Capture Rate - Total (%)': '48.0'}, {'Borough': 'Manhattan', 'District': 'MN10', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '12.7', 'Capture Rate - Paper (%)': '33.9', 'Capture Rate - MGP (%)': '48.2', 'Capture Rate - Total (%)': '40.0'}, {'Borough': 'Manhattan', 'District': 'MN11', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '10.7', 'Capture Rate - Paper (%)': '37.6', 'Capture Rate - MGP (%)': '29.5', 'Capture Rate - Total (%)': '34.2'}, {'Borough': 'Manhattan', 'District': 'MN12', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '15.1', 'Capture Rate - Paper (%)': '43.5', 'Capture Rate - MGP (%)': '54.4', 'Capture Rate - Total (%)': '48.2'}, {'Borough': 'Manhattan', 'District': 'MN01', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '25.4', 'Capture Rate - Paper (%)': '43.6', 'Capture Rate - MGP (%)': '61.8', 'Capture Rate - Total (%)': '48.5'}, {'Borough': 'Manhattan', 'District': 'MN02', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '22.3', 'Capture Rate - Paper (%)': '35.5', 'Capture Rate - MGP (%)': '64.7', 'Capture Rate - Total (%)': '43.4'}, {'Borough': 'Manhattan', 'District': 'MN03', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '12.7', 'Capture Rate - Paper (%)': '40.4', 'Capture Rate - MGP (%)': '40.0', 'Capture Rate - Total (%)': '40.2'}, {'Borough': 'Manhattan', 'District': 'MN04', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '21.3', 'Capture Rate - Paper (%)': '31.9', 'Capture Rate - MGP (%)': '67.0', 'Capture Rate - Total (%)': '41.4'}, {'Borough': 'Manhattan', 'District': 'MN05', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '17.9', 'Capture Rate - Paper (%)': '30.4', 'Capture Rate - MGP (%)': '46.5', 'Capture Rate - Total (%)': '34.8'}, {'Borough': 'Manhattan', 'District': 'MN06', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '21.0', 'Capture Rate - Pape ...
# [{'Borough': 'Queens East', 'District': 'QE07', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '16.9', 'Capture Rate - Paper (%)': '47.9', 'Capture Rate - MGP (%)': '51.3', 'Capture Rate - Total (%)': '49.2'}, {'Borough': 'Queens East', 'District': 'QE08', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '15.1', 'Capture Rate - Paper (%)': '28.3', 'Capture Rate - MGP (%)': '44.2', 'Capture Rate - Total (%)': '33.0'}, {'Borough': 'Queens East', 'District': 'QE10', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '15.9', 'Capture Rate - Paper (%)': '36.3', 'Capture Rate - MGP (%)': '64.4', 'Capture Rate - Total (%)': '46.3'}, {'Borough': 'Queens East', 'District': 'QE11', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '20.9', 'Capture Rate - Paper (%)': '55.0', 'Capture Rate - MGP (%)': '71.1', 'Capture Rate - Total (%)': '60.7'}, {'Borough': 'Queens East', 'District': 'QE12', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '12.8', 'Capture Rate - Paper (%)': '34.6', 'Capture Rate - MGP (%)': '50.0', 'Capture Rate - Total (%)': '42.0'}, {'Borough': 'Queens East', 'District': 'QE13', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '16.3', 'Capture Rate - Paper (%)': '34.2', 'Capture Rate - MGP (%)': '71.4', 'Capture Rate - Total (%)': '47.4'}, {'Borough': 'Queens East', 'District': 'QE14', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '10.6', 'Capture Rate - Paper (%)': '29.0', 'Capture Rate - MGP (%)': '33.8', 'Capture Rate - Total (%)': '30.9'}, {'Borough': 'Queens East', 'District': 'QE07', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '17.0', 'Capture Rate - Paper (%)': '48.6', 'Capture Rate - MGP (%)': '51.1', 'Capture Rate - Total (%)': '49.6'}, {'Borough': 'Queens East', 'District': 'QE08', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '15.1', 'Capture Rate - Paper (%)': '28.3', 'Capture Rate - MGP (%)': '43.5', 'Capture Rate - Total (%)': '32.8'}, {'Borough': 'Queens East', 'District': 'QE10', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '15.9', 'Capture Rate - Paper (%)': '36.7', 'Capture Rate - MGP (%)': '63.5', 'Capture Rate - Total (%)': '46.2'}, {'Borough': 'Queens East', 'District': 'QE11', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '21.2', 'Capture Rate - Paper (%)': '56.4', 'Capture Rate - MGP (%)': '71.4', 'Capture Rate - Total (%)': '61.7'}, {'Borough': 'Queens East', 'District': 'QE12', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '13.0', 'Capture Rate - Paper (%)': '34.7', 'Capture Rate - MGP (%)': '51.1', 'Capture Rate - Total (%)': '42.6'}, {'Borough': 'Queens East', 'District': 'QE13', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '16.4', 'Capture Rate - Paper (%)': '34.5', 'Capture Rate - MGP (%)': '71.5', 'Capture Rate - Total (%)': '47.6'}, {'Borough': 'Queens East', 'District': 'QE14', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '10.4', 'Capture Rate - Paper (%)': '28.5', 'Capture Rate - MGP (%)': '33.0', 'Capture Rate - Total (%)': '30.3'}, {'Borough': 'Queens East', 'District': 'QE07', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '17.4', 'Capture Rate - Paper (%)': '48.4', 'Capture Rate - MGP (%)': '65.0', 'Capture Rate - Total (%)': '54.0'}, {'Borough': 'Queens East', 'District': 'QE08', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '15.3', 'Capture Rate - Paper (%)': '28.2', 'Capture Rate - MGP (%)': '49.0', 'Capture Rate - Total (%)': '34.0'}, {'Borough': 'Queens East', 'District': 'QE10', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '16.5', 'Capture Rate - Paper (%)': '35.5', 'Capture Rate - MGP (%)': '74.1', 'Capture Rate - Total (%)': '47.7'}, {'Borough': 'Queens East', 'District': 'QE11', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rat ...
# [{'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '19.1', 'Capture Rate - Paper (%)': '39.9', 'Capture Rate - MGP (%)': '67.4', 'Capture Rate - Total (%)': '49.7'}, {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '18.4', 'Capture Rate - Paper (%)': '45.0', 'Capture Rate - MGP (%)': '68.9', 'Capture Rate - Total (%)': '53.5'}, {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2016', 'Fiscal Month': '01', 'Diversion Rate (%)': '19.5', 'Capture Rate - Paper (%)': '47.4', 'Capture Rate - MGP (%)': '73.6', 'Capture Rate - Total (%)': '56.7'}, {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '19.1', 'Capture Rate - Paper (%)': '40.5', 'Capture Rate - MGP (%)': '69.1', 'Capture Rate - Total (%)': '50.6'}, {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '18.7', 'Capture Rate - Paper (%)': '46.5', 'Capture Rate - MGP (%)': '68.2', 'Capture Rate - Total (%)': '54.2'}, {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2016', 'Fiscal Month': '02', 'Diversion Rate (%)': '19.9', 'Capture Rate - Paper (%)': '48.6', 'Capture Rate - MGP (%)': '74.7', 'Capture Rate - Total (%)': '57.9'}, {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '18.7', 'Capture Rate - Paper (%)': '39.5', 'Capture Rate - MGP (%)': '71.7', 'Capture Rate - Total (%)': '49.7'}, {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '19.0', 'Capture Rate - Paper (%)': '44.5', 'Capture Rate - MGP (%)': '75.0', 'Capture Rate - Total (%)': '54.1'}, {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2016', 'Fiscal Month': '03', 'Diversion Rate (%)': '20.3', 'Capture Rate - Paper (%)': '48.2', 'Capture Rate - MGP (%)': '79.5', 'Capture Rate - Total (%)': '58.1'}, {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '18.4', 'Capture Rate - Paper (%)': '39.3', 'Capture Rate - MGP (%)': '69.2', 'Capture Rate - Total (%)': '48.7'}, {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '19.2', 'Capture Rate - Paper (%)': '45.5', 'Capture Rate - MGP (%)': '71.0', 'Capture Rate - Total (%)': '53.5'}, {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2016', 'Fiscal Month': '04', 'Diversion Rate (%)': '20.0', 'Capture Rate - Paper (%)': '47.2', 'Capture Rate - MGP (%)': '76.4', 'Capture Rate - Total (%)': '56.4'}, {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '18.8', 'Capture Rate - Paper (%)': '37.4', 'Capture Rate - MGP (%)': '63.4', 'Capture Rate - Total (%)': '45.6'}, {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '17.4', 'Capture Rate - Paper (%)': '41.7', 'Capture Rate - MGP (%)': '64.1', 'Capture Rate - Total (%)': '48.7'}, {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2016', 'Fiscal Month': '05', 'Diversion Rate (%)': '18.1', 'Capture Rate - Paper (%)': '44.1', 'Capture Rate - MGP (%)': '66.6', 'Capture Rate - Total (%)': '51.2'}, {'Borough': 'Staten Island', 'District': 'SI01', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '20.7', 'Capture Rate - Paper (%)': '41.1', 'Capture Rate - MGP (%)': '65.0', 'Capture Rate - Total (%)': '48.7'}, {'Borough': 'Staten Island', 'District': 'SI02', 'Fiscal Year': '2016', 'Fiscal Month': '06', 'Diversion Rate (%)': '21.7', 'Capture Rate - Paper (%)': '48.8', 'Capture Rate - MGP (%)': '67.3', 'Capture Rate - Total (%)': '54.7'}, {'Borough': 'Staten Island', 'District': 'SI03', 'Fiscal Year': '2016',  ...

# %%
def filter_borough_by_year(lst, year):
    year = str(year)
    return [row for row in lst if year in row['Fiscal Year']]


bronx_2016 = filter_borough_by_year(bronx_list, 2016)
bronx_2017 = filter_borough_by_year(bronx_list, 2017)
bronx_2018 = filter_borough_by_year(bronx_list, 2018)
bronx_2019 = filter_borough_by_year(bronx_list, 2019)
brooklyn_2016 = filter_borough_by_year(brooklyn_list, 2016)
brooklyn_2017 = filter_borough_by_year(brooklyn_list, 2017)
brooklyn_2018 = filter_borough_by_year(brooklyn_list, 2018)
brooklyn_2019 = filter_borough_by_year(brooklyn_list, 2019)
manhattan_2016 = filter_borough_by_year(manhattan_list, 2016)
manhattan_2017 = filter_borough_by_year(manhattan_list, 2017)
manhattan_2018 = filter_borough_by_year(manhattan_list, 2018)
manhattan_2019 = filter_borough_by_year(manhattan_list, 2019)
queens_2016 = filter_borough_by_year(queens_list, 2016)
queens_2017 = filter_borough_by_year(queens_list, 2017)
queens_2018 = filter_borough_by_year(queens_list, 2018)
queens_2019 = filter_borough_by_year(queens_list, 2019)
staten_island_2016 = filter_borough_by_year(staten_island_list, 2016)
staten_island_2017 = filter_borough_by_year(staten_island_list, 2017)
staten_island_2018 = filter_borough_by_year(staten_island_list, 2018)
staten_island_2019 = filter_borough_by_year(staten_island_list, 2019)

# %%
def yearly_avg_div_rate(borough_year_lst):
    sum_div_rate = 0
    for row in borough_year_lst:
        sum_div_rate += float(row['Diversion Rate (%)'])
    return round(sum_div_rate / len(borough_year_lst), 1)

bronx_div_rate_2016 = yearly_avg_div_rate(bronx_2016)
bronx_div_rate_2017 = yearly_avg_div_rate(bronx_2017)
bronx_div_rate_2018 = yearly_avg_div_rate(bronx_2018)
bronx_div_rate_2019 = yearly_avg_div_rate(bronx_2019)
brooklyn_div_rate_2016 = yearly_avg_div_rate(brooklyn_2016)
brooklyn_div_rate_2017 = yearly_avg_div_rate(brooklyn_2017)
brooklyn_div_rate_2018 = yearly_avg_div_rate(brooklyn_2018)
brooklyn_div_rate_2019 = yearly_avg_div_rate(brooklyn_2019)
manhattan_div_rate_2016 = yearly_avg_div_rate(manhattan_2016)
manhattan_div_rate_2017 = yearly_avg_div_rate(manhattan_2017)
manhattan_div_rate_2018 = yearly_avg_div_rate(manhattan_2018)
manhattan_div_rate_2019 = yearly_avg_div_rate(manhattan_2019)
queens_div_rate_2016 = yearly_avg_div_rate(queens_2016)
queens_div_rate_2017 = yearly_avg_div_rate(queens_2017)
queens_div_rate_2018 = yearly_avg_div_rate(queens_2018)
queens_div_rate_2019 = yearly_avg_div_rate(queens_2019)
staten_island_div_rate_2016 = yearly_avg_div_rate(staten_island_2016)
staten_island_div_rate_2017 = yearly_avg_div_rate(staten_island_2017)
staten_island_div_rate_2018 = yearly_avg_div_rate(staten_island_2018)
staten_island_div_rate_2019 = yearly_avg_div_rate(staten_island_2019)

# %%
bronx_avg_div_dict = {}
brooklyn_avg_div_dict = {}
manhattan_avg_div_dict = {}
queens_avg_div_dict = {}
staten_island_avg_div_dict  = {}
bronx_avg_div_dict.update({"Bronx": {2016:bronx_div_rate_2016, 2017:bronx_div_rate_2017,2018:bronx_div_rate_2018, 2019:bronx_div_rate_2019}})
brooklyn_avg_div_dict.update({"Brooklyn": {2016:brooklyn_div_rate_2016, 2017:brooklyn_div_rate_2017, 2018:brooklyn_div_rate_2018, 2019:brooklyn_div_rate_2019}})
manhattan_avg_div_dict.update({"Manhattan": {2016: manhattan_div_rate_2016, 2017: manhattan_div_rate_2017, 2018: manhattan_div_rate_2018, 2019:manhattan_div_rate_2019}})
queens_avg_div_dict.update({"Queens": {2016: queens_div_rate_2016, 2017: queens_div_rate_2017, 2018: queens_div_rate_2018, 2019: queens_div_rate_2019}})
staten_island_avg_div_dict.update({"Staten Island": {2016: staten_island_div_rate_2016, 2017: staten_island_div_rate_2017, 2018: staten_island_div_rate_2018, 2019: staten_island_div_rate_2019}})

print("Average Diversion Rate for Each Borough by Year (As a percent:)")
print(bronx_avg_div_dict)
print(brooklyn_avg_div_dict)
print(manhattan_avg_div_dict)
print(queens_avg_div_dict)
print(staten_island_avg_div_dict)
# Out:
# Average Diversion Rate for Each Borough by Year (As a percent:)
# {'Bronx': {2016: 12.9, 2017: 13.2, 2018: 14.0, 2019: 14.4}}
# {'Brooklyn': {2016: 15.8, 2017: 16.4, 2018: 16.9, 2019: 16.9}}
# {'Manhattan': {2016: 20.0, 2017: 20.4, 2018: 20.4, 2019: 21.0}}
# {'Queens': {2016: 17.8, 2017: 18.8, 2018: 19.5, 2019: 19.4}}
# {'Staten Island': {2016: 19.8, 2017: 20.4, 2018: 20.6, 2019: 20.9}}

# %% [markdown]
# ### With knowing this data. DSNY could now now take action to set targets for diversion rate per borough. Provide incentive for high-performance. But also investigate low-performing areas for systemic issues (such as education, enforcement, infrastructure).

# %% [markdown]
# ### Now with that part of the analysis done. We will move forward with seeing how the capture rate for paper and MGP does across borough each year.

# %%
def avg_paper_avg_mgp_capture_rate_by_year(borough_year_list):
    total_paper_capture = 0
    total_mgp_capture = 0
    for row in borough_year_list:
        total_paper_capture += float(row['Capture Rate - Paper (%)'])
        total_mgp_capture += float(row['Capture Rate - MGP (%)'])
    return round(total_paper_capture/len(borough_year_list),1), round(total_mgp_capture/len(borough_year_list), 1)

avg_bronx_paper_capture_rate_2016, avg_bronx_mgp_capture_rate_2016 = avg_paper_avg_mgp_capture_rate_by_year(bronx_2016)
avg_bronx_paper_capture_rate_2017, avg_bronx_mgp_capture_rate_2017 = avg_paper_avg_mgp_capture_rate_by_year(bronx_2017)
avg_bronx_paper_capture_rate_2018, avg_bronx_mgp_capture_rate_2018 = avg_paper_avg_mgp_capture_rate_by_year(bronx_2018)
avg_bronx_paper_capture_rate_2019, avg_bronx_mgp_capture_rate_2019 = avg_paper_avg_mgp_capture_rate_by_year(bronx_2019)
avg_brooklyn_paper_capture_rate_2016, avg_brooklyn_mgp_capture_rate_2016 = avg_paper_avg_mgp_capture_rate_by_year(brooklyn_2016)
avg_brooklyn_paper_capture_rate_2017, avg_brooklyn_mgp_capture_rate_2017 = avg_paper_avg_mgp_capture_rate_by_year(brooklyn_2017)
avg_brooklyn_paper_cature_rate_2018, avg_brooklyn_mgp_capture_rate_2018 = avg_paper_avg_mgp_capture_rate_by_year(brooklyn_2018)
avg_brooklyn_paper_capture_rate_2019, avg_brooklyn_mgp_capture_rate_2019 = avg_paper_avg_mgp_capture_rate_by_year(brooklyn_2019)
avg_manhattan_paper_capture_rate_2016, avg_manhattan_mgp_capture_rate_2016 = avg_paper_avg_mgp_capture_rate_by_year(manhattan_2016)
avg_manhattan_paper_capture_rate_2017, avg_manhattan_mgp_capture_rate_2017 = avg_paper_avg_mgp_capture_rate_by_year(manhattan_2017)
avg_manhattan_paper_capture_rate_2018, avg_manhattan_mgp_capture_rate_2018 = avg_paper_avg_mgp_capture_rate_by_year(manhattan_2018)
avg_manhattan_paper_capture_rate_2019, avg_manhattan_mgp_capture_rate_2019 = avg_paper_avg_mgp_capture_rate_by_year(manhattan_2019)
avg_queens_paper_capture_rate_2016, avg_queens_mgp_capture_rate_2016 = avg_paper_avg_mgp_capture_rate_by_year(queens_2016)
avg_queens_paper_capture_rate_2017, avg_queens_mgp_capture_rate_2017 = avg_paper_avg_mgp_capture_rate_by_year(queens_2017)
avg_queens_paper_capture_rate_2018, avg_queens_mgp_capture_rate_2018 = avg_paper_avg_mgp_capture_rate_by_year(queens_2018)
avg_queens_paper_capture_rate_2019, avg_queens_mgp_capture_rate_2019 = avg_paper_avg_mgp_capture_rate_by_year(queens_2019)
avg_staten_island_paper_capture_rate_2016, avg_staten_island_mgp_capture_rate_2016 = avg_paper_avg_mgp_capture_rate_by_year(staten_island_2016)
avg_staten_island_paper_capture_rate_2017, avg_staten_island_mgp_capture_rate_2017 = avg_paper_avg_mgp_capture_rate_by_year(staten_island_2017)
avg_staten_island_paper_capture_rate_2018, avg_staten_island_mgp_capture_rate_2018 = avg_paper_avg_mgp_capture_rate_by_year(staten_island_2018)
avg_staten_island_paper_capture_rate_2019, avg_staten_island_mgp_capture_rate_2019 = avg_paper_avg_mgp_capture_rate_by_year(staten_island_2019)

# %%
def monthly_trend_total_capture_rate(borough_year_lst):
    month_trend_capture_rate_dict = {}
    for row in borough_year_lst:
        month_trend_capture_rate_dict[row['Fiscal Month']] = row['Capture Rate - Total (%)']
    return month_trend_capture_rate_dict

bronx_2016_monthly_trend = monthly_trend_total_capture_rate(bronx_2016)
bronx_20117_monthly_trend = monthly_trend_total_capture_rate(bronx_2017)
bronx_2018_monthly_trend = monthly_trend_total_capture_rate(bronx_2018)
bronx_2019_monthly_trend = monthly_trend_total_capture_rate(bronx_2019)
brooklyn_2016_monthly_trend = monthly_trend_total_capture_rate(brooklyn_2016)
brooklyn_2017_monthly_trend = monthly_trend_total_capture_rate(brooklyn_2017)
brooklyn_2018_monthly_trend = monthly_trend_total_capture_rate(brooklyn_2018)
brooklyn_2019_monthly_trend = monthly_trend_total_capture_rate(brooklyn_2019)
manhattan_2016_monthly_trend = monthly_trend_total_capture_rate(manhattan_2016)
manhattan_2017_monthly_trend = monthly_trend_total_capture_rate(manhattan_2017)
manhattan_2018_monthly_trend = monthly_trend_total_capture_rate(manhattan_2018)
manhattan_2019_monthly_trend = monthly_trend_total_capture_rate(manhattan_2019)
queens_2016_monthly_trend = monthly_trend_total_capture_rate(queens_2016)
queens_2017_monthly_trend = monthly_trend_total_capture_rate(queens_2017)
queens_2018_monthly_trend = monthly_trend_total_capture_rate(queens_2018)
queens_2019_monthly_trend = monthly_trend_total_capture_rate(queens_2019)
staten_island_2016_monthly_trend = monthly_trend_total_capture_rate(staten_island_2016)
staten_island_2017_monthly_trend = monthly_trend_total_capture_rate(staten_island_2017)
staten_island_2018_monthtly_trend = monthly_trend_total_capture_rate(staten_island_2018)
staten_island_2019_monthly_trend = monthly_trend_total_capture_rate(staten_island_2019)

# %%
def yearly_avg_total_capture_rate_per_borough(lst_1, lst_2, lst_3, lst_4, lst_5):
    sum_capture_rate = 0
    sum_capture_rate_one = 0
    sum_capture_rate_two = 0
    sum_capture_rate_three = 0
    sum_capture_rate_four = 0
    for row in lst_1:
        sum_capture_rate += float(row['Capture Rate - Total (%)'])
    for row in lst_2:
        sum_capture_rate_one += float(row['Capture Rate - Total (%)'])
    for row in lst_3:
        sum_capture_rate_two += float(row['Capture Rate - Total (%)'])
    for row in lst_4:
        sum_capture_rate_three += float(row['Capture Rate - Total (%)'])
    for row in lst_5:
        sum_capture_rate_four += float(row['Capture Rate - Total (%)'])
    return {'Bronx': round(sum_capture_rate / len(lst_1), 1), 'Brooklyn': round(sum_capture_rate_one / len(lst_2), 1),
           'Manhattan' : round(sum_capture_rate_two / len(lst_3), 1), 'Queens' : round(sum_capture_rate_three / len(lst_4), 1),
            'Staten Island': round(sum_capture_rate_four / len(lst_5), 1)}



yr_avg_total_capture_rate_2016 = yearly_avg_total_capture_rate_per_borough(bronx_2016, brooklyn_2016, manhattan_2016, queens_2016, staten_island_2016)
yr_avg_total_capture_rate_2017 = yearly_avg_total_capture_rate_per_borough(bronx_2017, brooklyn_2017, manhattan_2017, queens_2017, staten_island_2017) 
yr_avg_total_capture_rate_2018 = yearly_avg_total_capture_rate_per_borough(bronx_2018, brooklyn_2018, manhattan_2018, queens_2018, staten_island_2018)
yr_avg_total_capture_rate_2019 = yearly_avg_total_capture_rate_per_borough(bronx_2019, brooklyn_2019, manhattan_2019, queens_2019, staten_island_2019) 


print(yr_avg_total_capture_rate_2016)

def dictionary_to_list_for_selection_sort(yearly_avg_total_capture_rate_dict):
    list_to_be_sorted = [float(str_num) for str_num in yearly_avg_total_capture_rate_dict.values()]
    for i in range(len(list_to_be_sorted)):
        max_index = i
        for j in range(i + 1, len(list_to_be_sorted)):
            if list_to_be_sorted[j] > list_to_be_sorted[max_index]:
                max_index= j
        list_to_be_sorted[i], list_to_be_sorted[max_index] = list_to_be_sorted[max_index], list_to_be_sorted[i]
    

sorted_total_capture_rate_by_year_2016 = dictionary_to_list_for_selection_sort(yr_avg_total_capture_rate_2016)

def top_performing_borough_by_total_capture_rate_year(sorted_total_capture_rate_by_year_list, yr_avg_total_capture_rate_year):
    for total_capture_rate_num in sorted_total_capture_rate_by_year_list:
        if total_capture_rate_num in yr_avg_total_capture_rate_year:
# Out:
# {'Bronx': 38.9, 'Brooklyn': 43.9, 'Manhattan': 45.7, 'Queens': 49.1, 'Staten Island': 54.9}
# [54.9, 49.1, 45.7, 43.9, 38.9]
